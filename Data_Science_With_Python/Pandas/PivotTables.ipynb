# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    769     76   John
# 1  2023-01-02       B   West    140     20   Mary
# 2  2023-01-03       C  North    961     22    Bob
# 3  2023-01-04       D  South    286     93  Alice
# 4  2023-01-05       A   East    842     49   John
# 5  2023-01-06       B   West    700     17   Mary
# 6  2023-01-07       C  North    636     95    Bob
# 7  2023-01-08       D  South    838     31  Alice
# 8  2023-01-09       A   East    841     65   John
# 9  2023-01-10       B   West    700     70   Mary
# 10 2023-01-11       C  North    538     46    Bob
# 11 2023-01-12       D  South    279     38  Alice
# 12 2023-01-13       A   East    561     54   John
# 13 2023-01-14       B   West    758     95   Mary
# 14 2023-01-15       C  North    929     54    Bob
# 15 2023-01-16       D  South    160     91  Alice
# 16 2023-01-17       A   East    369     40   John
# 17 2023-01-18       B   West    721     49   Mary
# 18 2023-01-19       C  North    173     90    Bob
# 19 2023-01-20       D  South    815     84  Alice

# %%
pd.pivot_table(df,values="Sales",index='Region',columns="Product",aggfunc="max")
#COMMENT: values mean what to calculate , index means rows , columns mean columns  and in aggfunc we can write any statistic function like mean,median,max,min etc
# Out:
# Product      A      B      C      D
# Region
# East     842.0    NaN    NaN    NaN
# North      NaN    NaN  961.0    NaN
# South      NaN    NaN    NaN  838.0
# West       NaN  758.0    NaN    NaN

# %%
pivot2=pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
print(pivot2)
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     452.8    NaN    NaN    NaN  47.0   NaN   NaN   NaN
# North      NaN    NaN  568.8    NaN   NaN   NaN  80.0   NaN
# South      NaN    NaN    NaN  330.0   NaN   NaN   NaN  84.8
# West       NaN  484.8    NaN    NaN   NaN  66.2   NaN   NaN
